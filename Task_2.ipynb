# %% [markdown]
# # Задание 2.
#
# **NB. Все упражнения ниже нужно делать без использования циклов Python в явном (`while`, `for`) и неявном виде (list comprehension, `map`, `reduce` и пр)**
#
# Задания по манипуляциям с массивами чаще всего решаются в одно/два выражения.

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

A = np.random.randint(0, 100, size=(200, 50))
A
# Out:
# array([[67, 41, 36, ..., 41, 22,  6],
#        [61, 25, 61, ..., 16, 69, 92],
#        [13,  7,  2, ..., 74, 29, 97],
#        ...,
#        [48, 81, 42, ..., 33, 87, 75],
#        [99, 76, 93, ..., 55, 21, 73],
#        [99, 49, 13, ...,  9, 67, 37]])

# %% [markdown]
# # Задание 2.1 (2 балла)
#
# Сгенерируйте новый массив, в котором столбцы массива `A` переставлены в случайном порядке

# %%
A = np.transpose(A)
np.random.shuffle(A)
A = np.transpose(A)
A
# Out:
# array([[23, 53, 73, ..., 54, 66, 62],
#        [54, 53, 82, ..., 84, 33, 97],
#        [40, 74, 72, ..., 28, 67, 19],
#        ...,
#        [29, 91, 86, ..., 65, 21, 42],
#        [49, 68, 31, ..., 87, 32, 84],
#        [44, 19, 73, ..., 10, 67, 66]])

# %% [markdown]
# # Задание 2.2 (5 баллов)
#
# Сгенерируйте новый массив, который содержит только те строки массива `A`, в которых:
# - сумма элементов по четным столбцам (индексы $0, 2, \ldots$) больше среднего значения (по всему массиву) суммы элементов по нечетным столбцам (индексы $1, 3, \ldots$)

# %%
B = A[:, ::2]
C = A[:, 1::2]
B,C
# Out:
# (array([[23, 73, 28, ..., 19, 73, 66],
#         [54, 82, 43, ..., 57, 98, 33],
#         [40, 72, 37, ..., 69, 76, 67],
#         ...,
#         [29, 86, 93, ..., 17, 35, 21],
#         [49, 31, 54, ..., 74, 24, 32],
#         [44, 73, 31, ..., 24, 44, 67]]),
#  array([[53, 90, 70, ..., 27, 54, 62],
#         [53, 35, 98, ..., 70, 84, 97],
#         [74, 12, 85, ..., 50, 28, 19],
#         ...,
#         [91,  2, 60, ..., 57, 65, 42],
#         [68, 71, 97, ..., 22, 87, 84],
#         [19, 67,  1, ..., 97, 10, 66]]))

# %%
B_sum = B.sum(axis=1)
C_sum = C.sum(axis=1).mean()
D = A[B_sum > C_sum]
D
# Out:
# array([[40, 74, 72, ..., 28, 67, 19],
#        [99, 41, 47, ..., 82,  1, 66],
#        [12, 42, 26, ..., 67, 23, 27],
#        ...,
#        [74, 77, 29, ..., 25, 30, 70],
#        [49, 68, 31, ..., 87, 32, 84],
#        [44, 19, 73, ..., 10, 67, 66]])

# %% [markdown]
# # Задача 2.3 (3 балла)
#
# Найдите индекс строки массива `A`, в которой разница между максимальным и минимальным элементом максимальна

# %%
np.argmax(np.max(A, axis=1) - np.min(A, axis=1))
# Out:
# 8

# %% [markdown]
# # Задание 2.4 (7 баллов)
#
# Сгенерируйте массив той же размерности, что и `A`, но в котором каждый элемент заменен на его порядковый номер (начиная с 1) в отсортированном по возрастанию массиве из элементов `A`
#
# Если `A` выглядит так:
# $$
# \begin{pmatrix}
# 12 & 14\\
# 1 & 2
# \end{pmatrix}
# $$
# то результат должен быть
# $$
# \begin{pmatrix}
# 3 & 4\\
# 1 & 2
# \end{pmatrix}
# $$
#
# *Tip: рассмотрите возможность неоднократного применения [argsort()](https://numpy.org/doc/stable/reference/generated/numpy.ndarray.argsort.html)*

# %%
test_matrix = A.reshape(1, 10000)
test_matrix_next = test_matrix.argsort() + 1
arg_matrix = test_matrix_next.reshape(200, 50)
arg_matrix
# Out:
# array([[7127, 8745, 5746, ...,  400,  415,  423],
#        [2972, 2989, 5972, ..., 5932, 5199, 1352],
#        [8544, 6172, 6168, ..., 3663,  740, 3552],
#        ...,
#        [5011, 1981,  562, ...,  336, 3361, 9939],
#        [7635, 2904, 5292, ..., 6653, 5612,  333],
#        [6686, 9294, 5769, ..., 4154, 7601, 4661]], dtype=int64)

# %% [markdown]
# # Задание 2.5 (2 балла)
#
# Примените $\min-\max$ - нормализацию к строкам массива `A`. То есть нужно получить новый массивы, в каждой строке которого максимальный элементы равен $1$, минимальный - $0$.

# %%
New = (A - np.min(A)) / (np.max(A) - np.min(A))
New
# Out:
# array([[0.23232323, 0.53535354, 0.73737374, ..., 0.54545455, 0.66666667,
#         0.62626263],
#        [0.54545455, 0.53535354, 0.82828283, ..., 0.84848485, 0.33333333,
#         0.97979798],
#        [0.4040404 , 0.74747475, 0.72727273, ..., 0.28282828, 0.67676768,
#         0.19191919],
#        ...,
#        [0.29292929, 0.91919192, 0.86868687, ..., 0.65656566, 0.21212121,
#         0.42424242],
#        [0.49494949, 0.68686869, 0.31313131, ..., 0.87878788, 0.32323232,
#         0.84848485],
#        [0.44444444, 0.19191919, 0.73737374, ..., 0.1010101 , 0.67676768,
#         0.66666667]])

# %% [markdown]
# # Задание 2.6 (2 балла)
#
# Сгенерируйте новый трехмерный массив, размерности $10 \times 200 \times 50$. Подмассивы по нулевой оси должны состоять из элементов `A`, умноженных на $1 - 10$ соответственно

# %%
E = np.random.randint(10, 200, 50)
E
# Out:
# array([ 96, 116, 146, 168, 187, 163,  50, 159, 169, 161,  39,  11,  28,
#        138,  17,  93,  43, 105,  90,  52, 151, 114,  44, 161, 102,  13,
#         62, 187, 192,  68, 119, 115, 117,  92,  86, 170, 116,  48,  59,
#        132,  17,  23,  65, 134, 103, 128,  61, 194, 101,  92])

# %% [markdown]
# # Задание 2.7 (2 балла)
#
# Создайте новый массив, такой же размерности, как и `A`, в котором сначала сгруппированы четные столбцы `A`, потом  нечетные. Используйте [np.concat()](https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html)

# %%
A = np.concatenate((A[:, ::2], A[:, 1::2]), axis=1)
A
# Out:
# array([[23, 73, 28, ..., 27, 54, 62],
#        [54, 82, 43, ..., 70, 84, 97],
#        [40, 72, 37, ..., 50, 28, 19],
#        ...,
#        [29, 86, 93, ..., 57, 65, 42],
#        [49, 31, 54, ..., 22, 87, 84],
#        [44, 73, 31, ..., 97, 10, 66]])

# %% [markdown]
# # Задание 2.8 (2 балла)
#
# Посчитайте количество строк массива `A`, в который все элементы больше 5. Используйте [np.all()](https://numpy.org/doc/stable/reference/generated/numpy.all.html)

# %%
np.all(A > 5, axis=1).sum()
# Out:
# 11

# %% [markdown]
# # Задание 2.9 (2 балла)
#
# Поделите массив `A` горизонтально на 10 частей и создайте новый массив размерности $20 \times 50$, который является средним этих частей. Используйте [np.split()](https://numpy.org/doc/stable/reference/generated/numpy.split.html)

# %%
X = np.split(A, 10)
X = np.mean(X, axis = 0)
X, X.shape
# Out:
# (array([[31.8, 45.8, 59. , 41.5, 51.9, 54.8, 55.9, 50.1, 53.5, 53.9, 36.4,
#          42. , 69.5, 58.3, 35.9, 43.1, 50.3, 52.7, 55.4, 43.1, 42.2, 50.6,
#          51.2, 56.9, 66. , 61. , 54. , 61.6, 55.8, 53.9, 36.7, 51.3, 37.8,
#          55. , 47.8, 44.2, 46.4, 61.6, 44.4, 53.3, 37.6, 53.7, 33.1, 49.4,
#          49.7, 54.7, 29.3, 65.5, 60.7, 35.7],
#         [48.8, 46.2, 53.4, 53.6, 57.1, 60.2, 25.2, 51.1, 43. , 32.8, 63.4,
#          51.2, 48.9, 58.5, 57.1, 60.1, 31.6, 52.7, 56.3, 48. , 46.9, 30.9,
#          42.5, 45.4, 32. , 32.9, 44.7, 63.8, 61.9, 56.5, 49.9, 41.7, 51.3,
#          32.8, 56.4, 47.4, 43.9, 60.6, 53.4, 57.9, 66. , 45.8, 50.1, 78.6,
#          51.8, 37.4, 40.8, 44.7, 56.6, 51.9],
#         [47.9, 46.8, 38.1, 50.7, 65. , 41.2, 55.5, 44.9, 52.9, 49.6, 62.6,
#          33.3, 55.1, 28.2, 43.2, 44.8, 49.1, 61.1, 35.9, 30.1, 52.8, 52.7,
#          58.4, 60. , 45.7, 62. , 51.3, 62.3, 52.6, 43.2, 35.3, 62.5, 63.9,
#          43.3, 59.1, 48.9, 53.3, 45.7, 63.2, 56.2, 61.3, 63.1, 50.1, 47.1,
#          53.8, 74.4, 57.7, 69.4, 55.4, 48.7],
#         [42.6, 58. , 51.4, 49.9, 47.6, 58.3, 45.8, 53.9, 58.9, 30.4, 51.5,
#          51.2, 70.8, 45.8, 49.2, 41.4, 57.2, 64.5, 37.7, 34.4, 58.8, 59.9,
#          61.2, 40.9, 54.9, 49.3, 55.9, 41.3, 49.4, 51.3, 32.1, 43. , 46.6,
#          63.7, 53.1, 41.6, 34.5, 43.1, 47.3, 52.3, 41.6, 42.3, 38.5, 54.9,
#          59.5, 44.3, 40.4, 42.6, 59.6, 48.1],
#         [49.7, 42.6, 55.7, 65.9, 54.3, 47.5, 46.2, 57.5, 33.8, 52.7, 41.8,
#          46.4, 60.1, 49.8, 45.7, 63. , 36.8, 60.6, 38.8, 47.2, 43. , 44.2,
#          53.4, 54.3, 41.1, 53.2, 33.8, 44.5, 57.8, 40.9, 42.1, 49.8, 43.8,
#          44.3, 67.9, 46. , 60.2, 40. , 38.8, 51.3, 50.7, 49.4, 59.8, 58.7,
#          57.5, 61.4, 39.9, 46.6, 42.2, 47.5],
#         [59.8, 43.1, 46.1, 49.1, 38.2, 35.4, 48.4, 72.5, 54.3, 59.1, 44.6,
#          54.1, 40.1, 44.7, 41. , 46.7, 38.2, 47.2, 53.3, 55.1, 43.7, 48.3,
#          55.2, 41.3, 40.9, 45.2, 42.9, 59.3, 50.3, 57.6, 37.3, 49.3, 44.5,
#          48.9, 45.6, 54. , 42.8, 51. , 51.5, 54.4, 67.1, 44.3, 60.2, 75. ,
#          61.9, 52.3, 69.8, 46.6, 57.5, 32. ],
#         [51.6, 50.4, 61.6, 57.9, 47. , 65.5, 45.5, 45.8, 39.4, 55.1, 59.5,
#          44.2, 58.6, 55.7, 55.9, 35.5, 37.5, 31.8, 42.9, 50.1, 42.2, 57.3,
#          36.4, 42.5, 41.9, 49.1, 52.3, 48.2, 44.1, 40.9, 46.8, 48.8, 50.9,
#          42.4, 54.8, 47.9, 44.1, 54.9, 65.5, 68.5, 61.4, 63.3, 50.1, 48.5,
#          41.2, 59.8, 49.2, 59.5, 49.6, 35.5],
#         [62.4, 49. , 52.4, 41.3, 47. , 58.9, 42. , 41.8, 45.7, 56.5, 65.8,
#          59.9, 37.4, 36.8, 55.8, 49.6, 62.6, 67.9, 57.1, 60.8, 46.5, 50.1,
#          40.7, 56.8, 52.6, 36.3, 52.7, 68.7, 50.7, 57.1, 45.3, 47.6, 54.4,
#          50.6, 37. , 51.2, 56.8, 41.4, 37.1, 42.9, 43.7, 41.3, 37.1, 41.6,
#          43.6, 57.1, 52.6, 37.1, 66.2, 51.4],
#         [54.9, 43.7, 70.2, 40.7, 50.7, 49.2, 53.9, 48.3, 47.6, 44.4, 45.6,
#          39.5, 38.7, 61.7, 33.8, 61.7, 45. , 47. , 57.6, 52.2, 51. , 64.7,
#          39.9, 58.4, 37.3, 36.9, 48. , 57.9, 44.2, 41.5, 40.8, 41.4, 56. ,
#          50.6, 42. , 44.6, 42.1, 40.3, 66.9, 39.3, 48.6, 48.8, 51.4, 47.9,
#          64.8, 46. , 51.4, 63.8, 48.3, 47. ],
#         [66.1, 49.7, 35.4, 56.8, 49.8, 53.6, 54.3, 36.5, 52.2, 55.8, 56.9,
#          63.2, 51.3, 43.9, 66.2, 53.5, 65.7, 37.7, 45.8, 48.6, 50.2, 57. ,
#          42.8, 63. , 40.7, 48.6, 55.6, 56.4, 46.5, 50.7, 57.3, 49.8, 46.4,
#          51.6, 57.6, 59.6, 60.2, 48.2, 50.8, 48.8, 29.1, 67.2, 56.6, 51.3,
#          34.7, 50.2, 56. , 61.4, 56.8, 48.9],
#         [62.6, 63.3, 41.4, 35.1, 59.1, 68.4, 56.4, 54. , 41.1, 61. , 44.4,
#          47.6, 46.7, 69.4, 64.5, 64.8, 41.2, 43.9, 26.7, 58.7, 60.4, 59.9,
#          54.2, 49.1, 60.5, 58.9, 33.3, 47.8, 67.3, 49.1, 47.3, 54.5, 54.5,
#          26.5, 34.9, 54. , 31.1, 51.9, 41. , 32. , 54.1, 43.3, 31.7, 44.9,
#          43.1, 61.3, 45.4, 30.3, 47.7, 46.2],
#         [55.9, 42.1, 54.3, 42.2, 47.8, 57. , 46.9, 45.2, 42.8, 38.1, 36.1,
#          60.7, 48.5, 43.7, 51.9, 42.3, 57.5, 64. , 54.7, 57.8, 59.3, 48.9,
#          55.8, 53.7, 55.3, 37.9, 50.7, 46.3, 52.1, 43.2, 53.1, 49.8, 49.7,
#          58.9, 44.1, 48.6, 50.1, 61. , 47.9, 48.6, 64.2, 49.3, 58.3, 55. ,
#          59.6, 54.2, 65.3, 44.7, 50.3, 39.8],
#         [54.6, 37.5, 52.2, 45.3, 43.5, 27.1, 55.3, 60.2, 59.2, 55.2, 47.7,
#          55.5, 40.5, 49. , 60.3, 50.8, 70. , 67.4, 46.4, 52.9, 38.2, 54.8,
#          50.4, 43.9, 46.8, 53.9, 47.7, 34.3, 54.3, 47.4, 48. , 45.6, 17.1,
#          65.3, 48.2, 49.2, 37.6, 46.7, 42. , 45.8, 60.5, 50.3, 38.5, 45.8,
#          48. , 69.2, 55.1, 52.4, 48.8, 47.4],
#         [61.6, 42.1, 48. , 23.5, 41.8, 55. , 57. , 64.3, 69. , 34.9, 56. ,
#          66.9, 53.1, 37.9, 50.2, 41.2, 52. , 40.6, 65.6, 55.1, 75.6, 38.9,
#          43.1, 48.3, 41.7, 53.7, 45.7, 48.7, 41.1, 54.1, 56.2, 51. , 46.2,
#          40.9, 55. , 40.4, 56.3, 50.1, 50. , 38.8, 45. , 40.4, 61.9, 40.7,
#          52.8, 51.5, 40.5, 69.3, 51.1, 58.9],
#         [72.6, 41.3, 46.7, 54.3, 44.7, 58.2, 57. , 67.1, 46. , 45.2, 54. ,
#          44.1, 53.6, 42.6, 45.6, 36.7, 40.9, 49.1, 52.1, 38.7, 49. , 47.3,
#          49.6, 54.4, 62.6, 61.8, 46.5, 52.1, 44.9, 33.2, 40.9, 57.2, 60.8,
#          50.4, 47.7, 50.2, 42.4, 46.6, 51.6, 50.4, 59.2, 51.4, 44.4, 42.4,
#          53.9, 60. , 42.1, 45.3, 54.5, 51.2],
#         [70.1, 52.1, 59.4, 58.6, 42.5, 55.1, 49.1, 56.7, 34.9, 53.3, 40.6,
#          41. , 66.4, 62.4, 45.5, 59.2, 44.9, 42.8, 51.9, 59.1, 33.4, 44.9,
#          40.6, 44.5, 44.7, 51.6, 39.9, 38.8, 62.9, 68.8, 59.2, 45.9, 48.5,
#          40.8, 59.1, 38.4, 46. , 41.7, 55.8, 49.9, 28.4, 45.3, 52.6, 53.6,
#          38.6, 45. , 53.9, 61.4, 51. , 47.1],
#         [54.5, 62.5, 43.5, 61.4, 60.5, 61.2, 59.6, 48. , 47. , 44.9, 50.7,
#          45.4, 60.3, 72.9, 45.8, 54.5, 54.7, 42.3, 50.9, 42.4, 51.1, 39.8,
#          56.8, 50.9, 53.7, 56.5, 51.4, 47.7, 52.8, 56.1, 53.6, 42.2, 61. ,
#          35.9, 38.6, 52.7, 50. , 60.6, 29.2, 45.8, 44. , 44.5, 62.2, 47.8,
#          57.4, 37.6, 47.7, 50.5, 44.7, 55.3],
#         [44.3, 47.9, 38.5, 42.5, 53.3, 60.9, 54.1, 42.2, 40.9, 60.2, 37.5,
#          66.2, 70.7, 46.5, 52.5, 41.9, 62.6, 44.9, 62.1, 34. , 42.7, 29.3,
#          36.5, 35.7, 41.7, 52.5, 49.4, 41.8, 61.3, 43.6, 52.4, 44.6, 52.8,
#          39. , 56.4, 51.9, 53.4, 36.5, 39.6, 50.8, 49.5, 49.6, 48.6, 43.5,
#          53.1, 50.8, 68.3, 49.9, 48. , 51.6],
#         [41.8, 48.3, 53.7, 56.6, 48.5, 42.6, 60.5, 50.4, 53.4, 65.6, 45.6,
#          46.5, 41.3, 41.7, 49.2, 44.1, 54.9, 40.8, 43. , 69.8, 49.2, 42.2,
#          49. , 53.6, 39.9, 38.2, 59.7, 49.7, 58.9, 46.3, 54.7, 44.5, 47.1,
#          53.3, 45.7, 34.2, 54.3, 58.6, 37.1, 57.1, 32.8, 57.1, 42.8, 31.3,
#          39.3, 49. , 58.1, 40. , 60.8, 65.3],
#         [40.5, 37.8, 61.6, 52.2, 49.6, 47.1, 52.2, 54.6, 54.7, 51.8, 62.2,
#          49.8, 48.5, 52.5, 59.9, 60.6, 62.8, 40.3, 46.3, 38.3, 44. , 45.7,
#          44.5, 32.8, 61.3, 45.4, 46.1, 46.8, 51. , 39.4, 46.7, 44.7, 55.2,
#          59.1, 54.7, 38.3, 52.1, 68.8, 53.7, 48. , 47.2, 54.4, 43.1, 61.3,
#          31.8, 60.4, 54.8, 52.8, 50. , 61. ]]),
#  (20, 50))

# %% [markdown]
# # Задание 2.10 (4 балла)
#
# "Разверните" массив `A` в одномерный массив. Оставьте в нём только уникальные элементы в том же порядке, в котором они встречаются в массиве. Используйте [np.unique()](https://numpy.org/doc/stable/reference/generated/numpy.unique.html)

# %%
zew = np.unique(A, return_index=True)[1]
zew, zew.shape
# Out:
# (array([ 32,  10, 118, 220,  89,  19,  31,   4,  96, 113, 188,  59,  83,
#         134, 133, 160,  80, 237, 164,  15,  13, 239,  29,   0,   5,  61,
#          42,  47,   2, 129,  62,  12,  95,  74, 172,  76,  18,  28,  56,
#          53,  60,  11,  17,  38, 152, 174, 161, 240, 243,  58,   3,  21,
#         144,  25,  43, 185,  14,  72, 181, 168, 356,  68,  49, 136, 189,
#         403,  24,  34,  35,  79,  27,  45, 101,   1, 125, 103, 123, 251,
#          54,  20,   8, 117,  51,   6,  33, 127, 105, 156,  92,  90,  26,
#         312,  81,   9,  78,  37,  69,  36,  73, 162], dtype=int64),
#  (100,))

# %% [markdown]
# # Задание 2.11 (3 балла)
#
# Создайте одномерный массив размерности $200$, в котором каждый элемент - евклидово расстояние между соответствующей строкой `A` и "средней" строкой `A`

# %% [markdown]
# # Задание 2.12 (2 балла)
#
# Создайте новый массив, который состоит из элементов `A`, измененных по следующим правилам:
# - если элемент меньше $50$, то он умножается на $2$
# - в противном случае он умножается на $3$
#
# Используйте [np.where()](https://numpy.org/doc/stable/reference/generated/numpy.where.html)

# %%
G = np.where(A > 50, A, A*3)
G = np.where(A < 50, A, A*2)
G
# Out:
# array([[ 23, 146,  28, ...,  27, 108, 124],
#        [108, 164,  43, ..., 140, 168, 194],
#        [ 40, 144,  37, ..., 100,  28,  19],
#        ...,
#        [ 29, 172, 186, ..., 114, 130,  42],
#        [ 49,  31, 108, ...,  22, 174, 168],
#        [ 44, 146,  31, ..., 194,  10, 132]])

# %% [markdown]
# # Задание 2.13 (7 баллов)
#
# Разверните массив `A` в одномерный массив. Создайте три новых массива, подсчитав скользящие средние по окнам $3$, $5$, $10$. Найдите сумму этих массивов, выровнив из размерности нулями справа
#
# *Tip: реализуйте функцию, которая считает скользящее среднее. Используйте [np.cumsum()](https://numpy.org/doc/stable/reference/generated/numpy.cumsum.html) или [np.convolve()](https://numpy.org/doc/stable/reference/generated/numpy.convolve.html)*

# %%
new_A = A.reshape(1, 10000)
sum(np.cumsum(new_A) / 3), sum(np.cumsum(new_A) / 5), sum(np.cumsum(new_A) / 10)
# Out:
# (829051842.3333356, 497431105.4000016, 248715552.7000008)

# %% [markdown]
# # Задание 2.14 (8 баллов)
#
# Постройте график функции $$f(x) = (5  \sin(2x) - \cos^2(x) - 1 + |x^3| - x^2) / (x^2 + 1)$$
#
# и производной от этой функции.  Найдите минимум с помощью `scipy` и обозначьте его на графике. На этой же оси постройте графики скользящего среднего этой функции с окном $1$, $2$, $5$.

# %%
def F:
    return (5 * np.sin(2 * x) - np.power(np.cos(x), 2) - 1 + np.abs(np.power(x, 3)) - np.power(x, 2)) / (np.power(x, 2) + 1)
# Out:
#   Input In [14]
#     def F:
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Задание 2.15 (10 баллов)
#
# Есть следующий алгоритм семплинирования, на вход функции подается вектор из целых положительных чисел и число семплов.

# %%
from typing import List 

def sample(x: List[int], c: int) -> List[int]:
    assert len(x) > 0
    
    s = np.sum(x)
    res = []
    for _ in range(c):
        val = s * np.random.random()
        cur, idx = 0, 0        
        while cur + x[idx] <= val:
            cur += x[idx]
            idx += 1
            
        res.append(idx)
    return res

            
sample([50, 3, 1, 7, 20], 5)

# %% [markdown]
# Реализуйте данный алгоритм более оптимальным способом на массивах `numpy`, без использования циклов. Проверьте корректность и идентичность алгоритмов семплирования с помощью статистических тестов.

# %% [markdown]
# # Задание 2.16 (5 баллов)
#
# Есть следующий алгоритм "случайного блуждания"

# %%
import random 

def walk(n: int):
    cur_position = 0
    for i in range(n):
        cur_position += random.choice([-3, -1, 0, 2, 3])

    return cur_position

walk(10_000)

# %% [markdown]
# Реализуйте более эффективную версию с помощью `numpy`, сравните производительность (используя, например, magic `timeit`). Воспользовавшись [kdeplot()](https://seaborn.pydata.org/generated/seaborn.kdeplot.html) или аналогами, постройте график распределения значений `walk(10_000)` на каком-то разумном числе запусков.

# %% [markdown]
# # Задание 2.17 (5 баллов)
#
# Имеется функция, которая проделывает достаточно странные манипуляции с массивом `numpy`

# %%
import numpy.typing as npt

def strange_conv(a: npt.NDArray[np.float64]) -> np.float64:
    x = a.shape[0]
    y = a.shape[1]

    t = 1.
    for y in range(y - 5):
        for x in range(x - 3):
            c = 1.5 * a[y+1, x+2] - a[y+5, x+3] * a[y, x] + 0.2 * a[y+4, x]
            t = 0.2 * t + 0.8 * c

    return t


a = np.random.random((10000, 10000))
strange_conv(a)

# %% [markdown]
# Оптимизируйте данную функцию с помощью (2 на выбор):
# - [Numba](https://numba.pydata.org)
# - `Cython` (+5 баллов)
# - [Taichi](https://github.com/taichi-dev/taichi) (+5 баллов)
# - `Pythran `[[1]](https://pythran.readthedocs.io/en/latest/), [[2]](https://serge-sans-paille.github.io/pythran-stories/pythran-tutorial.html) (+2 балла)
#
# Сравните производительность.
